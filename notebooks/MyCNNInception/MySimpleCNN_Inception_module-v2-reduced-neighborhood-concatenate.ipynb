# %%
import os
from itertools import product

import numpy as np

from ml.eval import eval_model

print(os.getcwd())
os.chdir('/home/jelinek/recetox/')

from ml.pipeline import FeitDataPipeline
from ml.util import NeighborhoodImageDataGenerator, rename_keras_layer

from tensorflow import keras

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import schedules
from tensorflow.keras.callbacks import ReduceLROnPlateau

from cfg import *

from livelossplot import PlotLossesKerasTF

name = "MySimpleCNN_Inception_module-v2-reduced-neighborhood-concatenate"
# Out:
# /home/jelinek/recetox

# %%
class MySimpleCNNInceptionModule(FeitDataPipeline):

    def __init__(self, neighborhood_tiles: int, *args, **kwargs):

        self.neighborhood_tiles: int = neighborhood_tiles

        super().__init__(*args, **kwargs)

        self.model = self.get_compiled_model()
        self.params.name = name
        self.params.epochs = 200
        self.batch_size = 16
        self.params.tile_size=256



    def get_optimizer(self):
        lr_schedule = schedules.ExponentialDecay(
            initial_learning_rate=1e-2,
            decay_steps=80,
            decay_rate=0.1,
            staircase=True)

        return Adam(
            # learning_rate=0.1,
            learning_rate=lr_schedule,
            beta_1=0.99,
            beta_2=0.9999)



    @staticmethod
    def __get_basic_layers(model_idx: int):
        trained_base_model = keras.models.load_model('saved-models/frozen/MySimpleCnn_Feit-inceptionv2-reduced.h5')
        trained_base_model.trainable = False

        name_suffix = '_model_tile_' + str(model_idx)

        for i in range(len(trained_base_model.layers)):
            rename_keras_layer(trained_base_model, trained_base_model.layers[i],
                               trained_base_model.layers[i].name + name_suffix)

        last_layer = trained_base_model(trained_base_model.inputs, training=False)

        rename_keras_layer(trained_base_model, last_layer, last_layer.name + name_suffix)

        trained_base_model._name += name_suffix
        return trained_base_model.inputs[0], last_layer


    @staticmethod
    def get_compiled_model():
        neighborhood = 1
        neighborhood_size = 2 * neighborhood + 1


        neighborhood_networks = [MySimpleCNNInceptionModule.__get_basic_layers(model_idx)
                                 for model_idx in range(neighborhood_size ** 2)]

        outputs = [model[1] for model in neighborhood_networks]

        merge_layer = keras.layers.Concatenate()(outputs)

        x = keras.layers.Dense(units=12, activation='sigmoid')(merge_layer)

        output = keras.layers.Dense(units = 12, activation = 'softmax')(x)

        inputs = [model[0] for model in neighborhood_networks]
        model = keras.Model(inputs=inputs, outputs=output)
        model.summary()

        return model


    def _train_model(self, data_train, data_valid):

        reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                                      patience=30, min_lr=1e-4, verbose=1,
                                      cooldown=20)

        self.model.fit(data_train,
                       steps_per_epoch=250,
                       epochs=9,
                       shuffle=True,
                       validation_data=data_valid,
                       validation_freq=10,
                       verbose=1,
                       callbacks=[self.tensorboard, reduce_lr, PlotLossesKerasTF()])

    def get_data_loader_training(self):
        datagen_train = NeighborhoodImageDataGenerator(self.neighborhood_tiles, horizontal_flip=True, vertical_flip=True, samplewise_center=True,
                                           samplewise_std_normalization=True)
        tiles_per_axis = self.neighborhood_tiles * 2 + 1

        return datagen_train.flow_from_directory(directory=self.params.data_training, color_mode='rgb',
                                                 class_mode='categorical', batch_size=self.params.batch_size,
                                                 shuffle=True,
                                                 target_size=(self.params.tile_size * tiles_per_axis,
                                                              self.params.tile_size * tiles_per_axis))

    def get_data_loader_validation(self):
        datagen_valid = NeighborhoodImageDataGenerator(self.neighborhood_tiles, samplewise_center=True, samplewise_std_normalization=True)
        tiles_per_axis = self.neighborhood_tiles * 2 + 1

        return datagen_valid.flow_from_directory(directory=self.params.data_validation, color_mode='rgb',
                                                 class_mode='categorical', batch_size=self.params.batch_size,
                                                 shuffle=False,
                                                 target_size=(self.params.tile_size * tiles_per_axis,
                                                              self.params.tile_size * tiles_per_axis))

    def get_datagen_segmentation(self):
        return NeighborhoodImageDataGenerator(self.neighborhood_tiles, samplewise_center=True,
                                              samplewise_std_normalization=True)

# %%
pipeline = MySimpleCNNInceptionModule(neighborhood_tiles=1,
                                      train_data_dir='data/Feit_colon-annotation-tiles-256-1-neighborhood/data_train/',
                                      valid_data_dir='data/Feit_colon-annotation-tiles-256-1-neighborhood/data_valid/')
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1_model_tile_0 (InputLaye [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_1_model_tile_1 (InputLaye [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_1_model_tile_2 (InputLaye [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_1_model_tile_3 (InputLaye [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_1_model_tile_4 (InputLaye [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_1_model_tile_5 (InputLaye [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_1_model_tile_6 (InputLaye [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_1_model_tile_7 (InputLaye [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_1_model_tile_8 (InputLaye [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# MySimpleCnnFewerLayers_model_ti (None, 12)           1021060     input_1_model_tile_0[0][0]
# __________________________________________________________________________________________________
# MySimpleCnnFewerLayers_model_ti (None, 12)           1021060     input_1_model_tile_1[0][0]
# __________________________________________________________________________________________________
# MySimpleCnnFewerLayers_model_ti (None, 12)           1021060     input_1_model_tile_2[0][0]
# __________________________________________________________________________________________________
# MySimpleCnnFewerLayers_model_ti (None, 12)           1021060     input_1_model_tile_3[0][0]
# __________________________________________________________________________________________________
# MySimpleCnnFewerLayers_model_ti (None, 12)           1021060     input_1_model_tile_4[0][0]
# __________________________________________________________________________________________________
# MySimpleCnnFewerLayers_model_ti (None, 12)           1021060     input_1_model_tile_5[0][0]
# __________________________________________________________________________________________________
# MySimpleCnnFewerLayers_model_ti (None, 12)           1021060     input_1_model_tile_6[0][0]
# __________________________________________________________________________________________________
# MySimpleCnnFewerLayers_model_ti (None, 12)           1021060     input_1_model_tile_7[0][0]
# __________________________________________________________________________________________________
# MySimpleCnnFewerLayers_model_ti (None, 12)           1021060     input_1_model_tile_8[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 108)          0           MySimpleCnnFewerLayers_model_tile
#                                                                  MySimpleCnnFewerLayers_model_tile
#                                                                  MySimpleCnnFewerLayers_model_tile
#                                                                  MySimpleCnnFewerLayers_model_tile
#                                                                  MySimpleCnnFewerLayers_model_tile
#                                                                  MySimpleCnnFewerLayers_model_tile
#                                                                  MySimpleCnnFewerLayers_model_tile
#                                                                  MySimpleCnnFewerLayers_model_tile
#                                                                  MySimpleCnnFewerLayers_model_tile
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 12)           1308        concatenate_1[0][0]
# ==================================================================================================
# Total params: 9,190,848
# Trainable params: 1,308
# Non-trainable params: 9,189,540
# __________________________________________________________________________________________________

# %%
pipeline.execute_pipeline(perform_validation=False, perform_test_segmentation=False)
# Out:
# categorical_accuracy
# 	categorical_accuracy 	 (min:    0.703, max:    0.949, cur:    0.949)
# Loss
# 	loss             	 (min:    0.245, max:    1.321, cur:    0.245)
# lr
# 	lr               	 (min:    0.010, max:    0.010, cur:    0.010)

# %%
pipeline.save_pipeline()

# %%
pipeline = FeitDataPipeline.load_pipeline(pipeline_name=name)

# %%
path = Path('data/Kather_5000')
from util.data_manipulation_scripts import generate_image_annotation_pairs

tiffs, _ = generate_image_annotation_pairs(Path('data/Feit_colon-annotation'))
for tiff in tiffs:
    pipeline.perform_segmentation(tiff, step=256)
# Out:
# Segmenting file 1 out of 1
# Processing region 1 out of 104
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-fb221dad837d> in <module>
#       4 tiffs, _ = generate_image_annotation_pairs(Path('data/Feit_colon-annotation'))
#       5 for tiff in tiffs:
# ----> 6     pipeline.perform_segmentation(tiff, step=256)
#       7
#
# ~/recetox/src/ml/pipeline.py in perform_segmentation(self, img_path, step)
#     150             image_path = images_list[i]
#     151             destination_path = base_dir / image_path.name
# --> 152             segmenter.perform_segmentation(image_path, destination_path, step)
#     153
#     154     def _update_static_information(self):
#
# ~/recetox/src/image/segmentation.py in perform_segmentation(self, image_path, destination, step)
#     739                                                                                    self.neighborhood_size)
#     740
# --> 741         segmentation_algorithm.segmented_image_to_file(destination)
#
# ~/recetox/src/image/segmentation.py in segmented_image_to_file(self, destination, transparency)
#     504     def segmented_image_to_file(self, destination: Path, transparency: float = 0.4) -> None:
#     505
# --> 506         self.__process_image()
#     507
#     508         grid_region_size = self.region_size // self.step
#
# ~/recetox/src/image/segmentation.py in __process_image(self)
#     407
#     408             #  operation(self, region_with_border, x, y, margins)
# --> 409             self.__grid_generation(region_with_border, x, y, margins)
#     410
#     411             tile_idx += 1
#
# ~/recetox/src/image/segmentation.py in __grid_generation(self, region_numpy, x, y, margins)
#     491         if not is_image_empty(region_numpy):
#     492             segmentation_algo = self.__build_small_slide_segmenter(region_numpy, margins)
# --> 493             predictions = segmentation_algo.get_predictions()
#     494
#     495             grid_x = x // self.step
#
# ~/recetox/src/image/segmentation.py in get_predictions(self, combine_neighbors)
#     200                                              is_uniform=self.__region_class_sampler)
#     201
# --> 202         for region in iterator:
#     203             for grid_x, grid_y in product(range(region.min_x, region.max_x), range(region.min_y, region.max_y)):
#     204
#
# ~/recetox/src/util/algorithms.py in __next__(self)
#      92         self.__climb_to_root()
#      93
# ---> 94         self.__descend()
#      95
#      96         children = list(self.interval_tree.successors(self.current_node))
#
# ~/recetox/src/util/algorithms.py in __descend(self)
#      64
#      65         if not self.interval_tree.nodes[self.current_node][self.__PROCESSED]:
# ---> 66             while not self.is_uniform(self.current_node) and not self.__is_empty_interval(self.current_node):
#      67
#      68                 mid_x = (self.current_node.min_x + self.current_node.max_x) // 2
#
# ~/recetox/src/image/segmentation.py in __region_class_sampler(self, interval)
#     271
#     272             tile_stack = [self._extract_tile(grid_x, grid_y) for (grid_x, grid_y) in tile_coords_stack]
# --> 273             predictions = self.__predict_tile_stack(tile_stack, tile_coords_stack)
#     274
#     275             already_computed = set(sampled_points) - set(tile_coords_stack)
#
# ~/recetox/src/image/segmentation.py in __predict_tile_stack(self, tile_stack, tile_coords_stack)
#     315             input_generator = self.datagen_segmentation.flow(np.array(tile_stack), batch_size=len(tile_stack))
#     316             clf_input = next(input_generator)
# --> 317             y_batch_pred = self.model.predict(clf_input)
#     318             self.__update_mapping(tile_coords_stack, y_batch_pred)
#     319
#
# ~/anaconda3/envs/recetox/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1725           for step in data_handler.steps():
#    1726             callbacks.on_predict_batch_begin(step)
# -> 1727             tmp_batch_outputs = self.predict_function(iterator)
#    1728             if data_handler.should_sync:
#    1729               context.async_wait()
#
# ~/anaconda3/envs/recetox/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/anaconda3/envs/recetox/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     931       # This is the first call of __call__, so we have to initialize.
#     932       initializers = []
# --> 933       self._initialize(args, kwds, add_initializers_to=initializers)
#     934     finally:
#     935       # At this point we know that the initialization is complete (or less
#
# ~/anaconda3/envs/recetox/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     761     self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     762     self._concrete_stateful_fn = (
# --> 763         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     764             *args, **kwds))
#     765
#
# ~/anaconda3/envs/recetox/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    3048       args, kwargs = None, None
#    3049     with self._lock:
# -> 3050       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3051     return graph_function
#    3052
#
# ~/anaconda3/envs/recetox/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3442
#    3443           self._function_cache.missed.add(call_context_key)
# -> 3444           graph_function = self._create_graph_function(args, kwargs)
#    3445           self._function_cache.primary[cache_key] = graph_function
#    3446
#
# ~/anaconda3/envs/recetox/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3277     arg_names = base_arg_names + missing_arg_names
#    3278     graph_function = ConcreteFunction(
# -> 3279         func_graph_module.func_graph_from_py_func(
#    3280             self._name,
#    3281             self._python_function,
#
# ~/anaconda3/envs/recetox/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     997         _, original_func = tf_decorator.unwrap(python_func)
#     998
# --> 999       func_outputs = python_func(*func_args, **func_kwargs)
#    1000
#    1001       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~/anaconda3/envs/recetox/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     670         # the function a weak reference to itself to avoid a reference cycle.
#     671         with OptionalXlaContext(compile_with_xla):
# --> 672           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     673         return out
#     674
#
# ~/anaconda3/envs/recetox/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     984           except Exception as e:  # pylint:disable=broad-except
#     985             if hasattr(e, "ag_error_metadata"):
# --> 986               raise e.ag_error_metadata.to_exception(e)
#     987             else:
#     988               raise
#
# ValueError: in user code:
#
#     /home/jelinek/anaconda3/envs/recetox/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1569 predict_function  *
#         return step_function(self, iterator)
#     /home/jelinek/anaconda3/envs/recetox/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1559 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /home/jelinek/anaconda3/envs/recetox/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:1285 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /home/jelinek/anaconda3/envs/recetox/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:2833 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /home/jelinek/anaconda3/envs/recetox/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:3608 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /home/jelinek/anaconda3/envs/recetox/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1552 run_step  **
#         outputs = model.predict_step(data)
#     /home/jelinek/anaconda3/envs/recetox/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1525 predict_step
#         return self(x, training=False)
#     /home/jelinek/anaconda3/envs/recetox/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py:1013 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /home/jelinek/anaconda3/envs/recetox/lib/python3.8/site-packages/tensorflow/python/keras/engine/input_spec.py:267 assert_input_compatibility
#         raise ValueError('Input ' + str(input_index) +
#
#     ValueError: Input 0 is incompatible with layer model_1: expected shape=(None, 256, 256, 3), found shape=(None, 85, 85, 3)
