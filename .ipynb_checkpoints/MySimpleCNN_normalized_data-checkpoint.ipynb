# %%
import os
os.getcwd()
os.chdir('/home/tomas/recetox/')

# %%
from ml.pipeline import ModelPipeline

from tensorflow import keras

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import schedules

from tensorflow.keras.callbacks import ReduceLROnPlateau

from cfg import *

from livelossplot import PlotLossesKerasTF

class MySimpleCNN(ModelPipeline):

    def perform_samplewise_std_normalization(cls):
        return True

    def get_color_normalization_method(cls):
        return None

    def get_name(cls):
        return cls.name

    def __init__(cls, *args, **kwargs):
        super().__init__(*args, **kwargs)

        cls.model = cls.get_compiled_model()
        cls.name = "MySimpleCNN"

        cls.epochs = 140
        cls.batch_size = 16

    @staticmethod
    def get_compiled_model():
        inputs = keras.Input(shape=(150, 150, 3))

        x = keras.layers.Conv2D(filters=32, kernel_size=5, strides=(1, 1), padding='same')(inputs)
        x = keras.layers.MaxPooling2D()(x)
        for i in range(7):
            #x = keras.layers.Dropout(rate=0.2)(x)
            x = keras.layers.Conv2D(filters=64 * (2 ** (i // 4)), kernel_size=5, strides=(1, 1), padding='same')(x)
            x = keras.layers.MaxPooling2D(padding='same', pool_size=(2, 2))(x)
            x = keras.layers.BatchNormalization(axis=3, epsilon=1.001e-5)(x)

        x = keras.layers.Flatten()(x)
        outputs = keras.layers.Dense(units=CLASSES, activation='softmax')(x)

        model = keras.Model(inputs, outputs, name='MySimpleCnn')
        model.summary()
        return model

    def _train_model(cls, data_train, data_valid):
        lr_schedule = schedules.ExponentialDecay(
            initial_learning_rate=1e-2,
            decay_steps=TRAINING_EXAMPLES_COUNT // cls.batch_size * 65,
            decay_rate=0.1,
            staircase=True)

        cls.optimizer = Adam(
            # learning_rate=0.1,
            learning_rate=lr_schedule,
            beta_1=0.99,
            beta_2=0.9999)

        reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                                      patience=30, min_lr=1e-4, verbose=1,
                                      cooldown=20)

        cls.model.fit(data_train,
                       steps_per_epoch=TRAINING_EXAMPLES_COUNT // cls.batch_size,
                       epochs=cls.epochs,
                       shuffle=True,
                       validation_data=data_valid,
                       validation_freq=1,
                       verbose=1,
                       callbacks=[cls.tensorboard, reduce_lr, PlotLossesKerasTF()])

# %%
from data_loader.data_loader import DataLoader

data_loader = DataLoader()

pipeline = MySimpleCNN(data_loader)

pipeline.execute_pipeline(perform_validation=True, perform_segmentation=True)
# Out:
# categorical_accuracy
# 	training         	 (min:    0.561, max:    0.762, cur:    0.762)
# 	validation       	 (min:    0.618, max:    0.715, cur:    0.695)
# Loss
# 	training         	 (min:    0.664, max:    1.225, cur:    0.664)
# 	validation       	 (min:    0.769, max:    1.005, cur:    0.876)
# lr
# 	lr               	 (min:    0.010, max:    0.010, cur:    0.010)
# 250/250 [==============================] - 8s 31ms/step - loss: 0.6642 - categorical_accuracy: 0.7615 - val_loss: 0.8756 - val_categorical_accuracy: 0.6950
# Epoch 5/140
# 142/250 [================>.............] - ETA: 2s - loss: 0.5894 - categorical_accuracy: 0.7905
