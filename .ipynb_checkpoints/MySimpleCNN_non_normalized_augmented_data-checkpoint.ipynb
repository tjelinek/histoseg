# %%
import os
print(os.getcwd())
os.chdir('/home/tomas/recetox/')

from ml.pipeline import ModelPipeline

from tensorflow import keras

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import schedules

from tensorflow.keras.callbacks import ReduceLROnPlateau

from cfg import *

from livelossplot import PlotLossesKerasTF

model_name = 'MySimpleCNN_non_norm_aug_data'
# Out:
# /home/tomas/recetox/src

# %%
class MySimpleCNN(ModelPipeline):

    def __init__(cls, *args, **kwargs):
        super().__init__(*args, **kwargs)

        cls.model = cls.get_compiled_model()
        cls.set_name(model_name)
        cls.set_num_of_training_epochs(300)
        cls.set_batch_size(16)

        lr_schedule = schedules.ExponentialDecay(
            initial_learning_rate=1e-2,
            decay_steps=TRAINING_EXAMPLES_COUNT // cls.get_batch_size() * 30,
            decay_rate=0.1,
            staircase=True)

        cls.optimizer = Adam(
            learning_rate=0.1,
            #learning_rate=lr_schedule,
            beta_1=0.99,
            beta_2=0.9999)

    @staticmethod
    def get_compiled_model():
        inputs = keras.Input(shape=(150, 150, 3))

        x = keras.layers.Conv2D(filters=32, kernel_size=5, strides=(1, 1), padding='same')(inputs)
        x = keras.layers.MaxPooling2D()(x)
        for i in range(7):
            #x = keras.layers.Dropout(rate=0.2)(x)
            x = keras.layers.Conv2D(filters=64 * (2 ** (i // 4)), kernel_size=5, strides=(1, 1), padding='same')(x)
            x = keras.layers.MaxPooling2D(padding='same', pool_size=(2, 2))(x)
            x = keras.layers.BatchNormalization(axis=3, epsilon=1.001e-5)(x)

        x = keras.layers.Flatten()(x)
        outputs = keras.layers.Dense(units=CLASSES, activation='softmax')(x)

        model = keras.Model(inputs, outputs, name='MySimpleCnn')
        model.summary()
        return model

    def _train_model(cls, data_train, data_valid):

        reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                                      patience=30, min_lr=1e-4, verbose=1,
                                      cooldown=20)

        cls.model.fit(data_train,
                       steps_per_epoch=TRAINING_EXAMPLES_COUNT * 10 // cls.get_batch_size(),
                       epochs=cls.get_num_of_training_epochs(),
                       shuffle=True,
                       validation_data=data_valid,
                       validation_freq=1,
                       verbose=1,
                       callbacks=[cls.tensorboard, reduce_lr, PlotLossesKerasTF()])

# %%
import time


pipeline = MySimpleCNN(train_data_dir='data/data_tiles_train_augmented',
                        valid_data_dir='data/data_tiles_valid')

pipeline.execute_pipeline(perform_validation=True, perform_test_segmentation=False)
# Out:
# categorical_accuracy
# 	training         	 (min:    0.668, max:    1.000, cur:    1.000)
# 	validation       	 (min:    0.658, max:    0.903, cur:    0.893)
# Loss
# 	training         	 (min:    0.001, max:    0.842, cur:    0.002)
# 	validation       	 (min:    0.428, max:    1.149, cur:    0.741)
# lr
# 	lr               	 (min:    0.000, max:    0.010, cur:    0.000)
# 2500/2500 [==============================] - 148s 59ms/step - loss: 0.0016 - categorical_accuracy: 0.9999 - val_loss: 0.7411 - val_categorical_accuracy: 0.8930
# Epoch 240/300
#  - ETA: 1:34 - loss: 0.0015 - categorical_accuracy: 0.9999

# %%
pipeline.save_pipeline()

# %%
pipeline = ModelPipeline.load_pipeline(pipeline_name=model_name)
pipeline.perform_segmentation()

#'data/Kather_texture_2016_larger_images_10/CRC-Prim-HE-06_APPLICATION.tif'
